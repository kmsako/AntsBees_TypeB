# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pandoc is already the newest version (1.19.2.4~dfsg-1build4).
# pandoc set to manually installed.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono fonts-texgyre
#   javascript-common libcupsfilters1 libcupsimage2 libgs9 libgs9-common
#   libijs-0.35 libjbig2dec0 libjs-jquery libkpathsea6 libpotrace0 libptexenc1
#   libruby2.5 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13 lmodern
#   poppler-data preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration t1utils tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
# Suggested packages:
#   fonts-noto apache2 | lighttpd | httpd poppler-utils ghostscript
# ...

# %%
# %pwd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/AntsBees')

# %%
# !cp /content/gdrive/My Drive/Colab Notebooks/AntsBees/TypeB_AntsBees_VGG16_PyTorch_DataSet.ipynb ./
# !jupyter nbconvert --to PDF "TypeB_AntsBees_VGG16_PyTorch_DataSet.ipynb"
# Out:
# cp: cannot stat '/content/gdrive/My': No such file or directory
# cp: cannot stat 'Drive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/AntsBees/TypeB_AntsBees_VGG16_PyTorch_DataSet.ipynb': No such file or directory
# [NbConvertApp] WARNING | pattern u'TypeB_AntsBees_VGG16_PyTorch_DataSet.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb) to various other
# formats.
#
# WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# -------
#
# Arguments that take values are actually convenience aliases to full
# Configurables, whose aliases are listed on the help line. For more information
# on full configurables, see '--help-all'.
#
# --execute
#     Execute the notebook prior to export.
# --allow-errors
# ...

# %%
# !cp /content/gdrive/My Drive/Colab Notebooks/AntsBees/TypeB_AntsBees_VGG16_PyTorch_Training_for_loop_dataloader_03.ipynb ./
# !jupyter nbconvert --to PDF "TypeB_AntsBees_VGG16_PyTorch_Training_for_loop_dataloader_03.ipynb"
# Out:
# cp: cannot stat '/content/gdrive/My': No such file or directory
# cp: cannot stat 'Drive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/AntsBees/TypeB_AntsBees_VGG16_PyTorch_Training_for_loop_dataloader_03.ipynb': No such file or directory
# [NbConvertApp] Converting notebook TypeB_AntsBees_VGG16_PyTorch_Training_for_loop_dataloader_03.ipynb to PDF
# [NbConvertApp] Writing 96506 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 65617 bytes to TypeB_AntsBees_VGG16_PyTorch_Training_for_loop_dataloader_03.pdf

# %%
# !cp /content/gdrive/My Drive/Colab Notebooks/AntsBees/TypeB_AntsBees_VGG16_PyTorch_Training_5.ipynb ./pdf/
# !jupyter nbconvert --to PDF "TypeB_AntsBees_VGG16_PyTorch_Training_5.ipynb"
# Out:
# cp: target './pdf/' is not a directory
# [NbConvertApp] Converting notebook TypeB_AntsBees_VGG16_PyTorch_Training_5.ipynb to PDF
# [NbConvertApp] Support files will be in TypeB_AntsBees_VGG16_PyTorch_Training_5_files/
# [NbConvertApp] Making directory ./TypeB_AntsBees_VGG16_PyTorch_Training_5_files
# [NbConvertApp] Making directory ./TypeB_AntsBees_VGG16_PyTorch_Training_5_files
# [NbConvertApp] Writing 111137 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 419444 bytes to TypeB_AntsBees_VGG16_PyTorch_Training_5.pdf

# %%
# !cp /content/gdrive/My Drive/Colab Notebooks/AntsBees/TypeB_AntsBees_VGG16_PyTorch_DataSet_02.ipynb ./pdf/
# !jupyter nbconvert --to PDF "TypeB_AntsBees_VGG16_PyTorch_DataSet_02.ipynb"
# Out:
# cp: cannot stat '/content/gdrive/My': No such file or directory
# cp: cannot stat 'Drive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/AntsBees/TypeB_AntsBees_VGG16_PyTorch_DataSet_02.ipynb': No such file or directory
# [NbConvertApp] Converting notebook TypeB_AntsBees_VGG16_PyTorch_DataSet_02.ipynb to PDF
# [NbConvertApp] Writing 36129 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 37756 bytes to TypeB_AntsBees_VGG16_PyTorch_DataSet_02.pdf

# %%
# !cp　 '/content/gdrive/My Drive/Colab　Notebooks/AntsBees/TypeB_AntsBees_PyTorch_ModelClass_02.ipynb' ./pdf/
# !jupyter nbconvert --to PDF "TypeB_AntsBees_PyTorch_ModelClass_02.ipynb"
# Out:
# /bin/bash: cp　: command not found
# [NbConvertApp] Converting notebook TypeB_AntsBees_PyTorch_ModelClass_02.ipynb to PDF
# [NbConvertApp] Writing 40278 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 40595 bytes to TypeB_AntsBees_PyTorch_ModelClass_02.pdf
